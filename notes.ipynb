# %% [markdown]
# # Setup
# Install the requirements
#
# You may need to install Firefox, and add geckodriver to `PATH`

# %%
# !pip install -r requirements.txt
# %load_ext autoreload
# %autoreload 2

import numpy as np
# Out:
# Requirement already satisfied: beautifulsoup4==4.7.1 in ./venv/lib/python3.7/site-packages (from -r requirements.txt (line 1)) (4.7.1)
# Requirement already satisfied: pandas==0.24.2 in ./venv/lib/python3.7/site-packages (from -r requirements.txt (line 2)) (0.24.2)
# Requirement already satisfied: requests==2.21.0 in ./venv/lib/python3.7/site-packages (from -r requirements.txt (line 3)) (2.21.0)
# Requirement already satisfied: tqdm==4.31.1 in ./venv/lib/python3.7/site-packages (from -r requirements.txt (line 4)) (4.31.1)
# Requirement already satisfied: selenium==3.141.0 in ./venv/lib/python3.7/site-packages (from -r requirements.txt (line 5)) (3.141.0)
# Requirement already satisfied: soupsieve>=1.2 in ./venv/lib/python3.7/site-packages (from beautifulsoup4==4.7.1->-r requirements.txt (line 1)) (1.9.1)
# Requirement already satisfied: numpy>=1.12.0 in ./venv/lib/python3.7/site-packages (from pandas==0.24.2->-r requirements.txt (line 2)) (1.16.2)
# Requirement already satisfied: python-dateutil>=2.5.0 in ./venv/lib/python3.7/site-packages (from pandas==0.24.2->-r requirements.txt (line 2)) (2.8.0)
# Requirement already satisfied: pytz>=2011k in ./venv/lib/python3.7/site-packages (from pandas==0.24.2->-r requirements.txt (line 2)) (2019.1)
# Requirement already satisfied: idna<2.9,>=2.5 in ./venv/lib/python3.7/site-packages (from requests==2.21.0->-r requirements.txt (line 3)) (2.8)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in ./venv/lib/python3.7/site-packages (from requests==2.21.0->-r requirements.txt (line 3)) (1.24.1)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in ./venv/lib/python3.7/site-packages (from requests==2.21.0->-r requirements.txt (line 3)) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.7/site-packages (from requests==2.21.0->-r requirements.txt (line 3)) (2019.3.9)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.7/site-packages (from python-dateutil>=2.5.0->pandas==0.24.2->-r requirements.txt (line 2)) (1.12.0)
# You are using pip version 10.0.1, however version 19.0.3 is available.
# You should consider upgrading via the 'pip install --upgrade pip' command.

# %% [markdown]
# # Gather ABC lower-house data

# %%
import election2019.abc

# %% [markdown]
# # Build initial dataframes
# Scrape candidate and electorate data from the ABC's website

# %% [markdown]
# ## Candidates

# %%
candidates = election2019.abc.build_candidates()

# %%
candidates
# Out:
#                        first_name   family_name party       electorate  \
# Aaron Hammond               Aaron       Hammond   SCP           Sydney
# Aaron Harpley-Carr          Aaron  Harpley-Carr   UAP           Dobell
# Aaron Santelises            Aaron    Santelises   ALP        McPherson
# Aaron Whittaker             Aaron     Whittaker   UAP         Brisbane
# Adam Bandt                   Adam         Bandt   GRN        Melbourne
# Adam Blakester               Adam     Blakester   IND      New England
# Adam Holt                    Adam          Holt   UAP           Sydney
# Adam Pulford                 Adam       Pulford   GRN            Wills
# Adam Veitch                  Adam        Veitch   UAP          Bendigo
# Adam Watson                  Adam        Watson   UAP  Kingsford Smith
# Alan Quinn                   Alan         Quinn   GRN        McPherson
# Alan Tudge                   Alan         Tudge   LIB            Aston
# Alex Hawke                   Alex         Hawke   LIB         Mitchell
# Ali France                    Ali        France   ALP          Dickson
# Alice Thompson              Alice      Thompson   IND        Mackellar
# Alicia Payne               Alicia         Payne   ALP         Canberra
# Alicia Walker              Alicia        Walker   AJP          Higgins
# Allan Green                 Allan         Green   LIB         Greenway
# Allan Roark                 Allan         Roark   UAP             Bass
# Alyce Nelligan              Alyce      Nelligan   GRN            Groom
# Amanda Rishworth           Amanda     Rishworth   ALP         Kingston
# Amanda Wilmot              Amanda        Wilmot   LIB  Kingsford Smith
# Amanda-Sue Markham     Amanda-Sue       Markham   LIB            Clark
# Amber Forbes                Amber        Forbes   GRN            Corio
# Amy Byrnes                    Amy        Byrnes   AJP          Hinkler
# Amy Gregorovich               Amy   Gregorovich   GRN         La Trobe
# Andrea Broadfoot           Andrea     Broadfoot    CA             Grey
# Andrew Bartlett            Andrew      Bartlett   GRN         Brisbane
# Andrew Bock                Andrew          Bock   IND         Nicholls
# Andrew Braddock            Andrew      Braddock   GRN           Fenner
# ...                           ...           ...   ...              ...
# Tony Smith                   Tony         Smith   LIB            Casey
# Tony Zappia                  Tony        Zappia   ALP            Makin
# Tracey Bell                Tracey          Bell   ALP        Moncrieff
# Tracey Burton              Tracey        Burton   GRN           Fisher
# Travis Barker              Travis        Barker   AJP            Casey
# Travis Carter              Travis        Carter   ONP            Brand
# Trent Zimmerman             Trent     Zimmerman   LIB     North Sydney
# Trevor Evans               Trevor         Evans   LNP         Brisbane
# Trevor Gray                Trevor          Gray   UAP           Fisher
# Trevor Jones               Trevor         Jones   IND          Boothby
# Troy Kay                     Troy           Kay   ALP            Groom
# Tyler Walsh                 Tyler         Walsh   ONP            Moore
# Vaughan Williams          Vaughan      Williams   ONP          Bendigo
# Vince Connelly              Vince      Connelly   LIB         Stirling
# Vinita Costantino          Vinita    Costantino   AJP           Deakin
# Virginia Thomas-Wurth    Virginia  Thomas-Wurth   AJP             Swan
# Wade Rothery                 Wade       Rothery   ONP      Capricornia
# Warnar Spyker              Warnar        Spyker   AUC             Burt
# Warren Entsch              Warren        Entsch   LNP       Leichhardt
# Warren Mundine             Warren       Mundine   LIB          Gilmore
# Warren Snowdon             Warren       Snowdon   ALP         Lingiari
# Wayne Connolly              Wayne      Connolly   UAP        Goldstein
# Wayne Sanford               Wayne       Sanford   ALP          Forrest
# Wayne Swan                  Wayne          Swan   ALP           Lilley
# William Hornstra          William      Hornstra   GRN           Monash
# Wylie Campbell              Wylie      Campbell   GRN        Shortland
# Yvonne Langenberg          Yvonne    Langenberg   ALP      New England
# Zac Beers                     Zac         Beers   ALP            Flynn
# Zali Steggall                Zali      Steggall   IND        Warringah
# Zephlyn Taylor            Zephlyn        Taylor   GRN           Wannon
#
#                        sitting website twitter facebook instagram
# Aaron Hammond            False
# Aaron Harpley-Carr       False
# Aaron Santelises         False
# Aaron Whittaker          False
# Adam Bandt                True
# Adam Blakester           False
# Adam Holt                False
# Adam Pulford             False
# Adam Veitch              False
# Adam Watson              False
# Alan Quinn               False
# Alan Tudge                True
# Alex Hawke                True
# Ali France               False
# Alice Thompson           False
# Alicia Payne             False
# Alicia Walker            False
# Allan Green              False
# Allan Roark              False
# Alyce Nelligan           False
# Amanda Rishworth          True
# Amanda Wilmot            False
# Amanda-Sue Markham       False
# Amber Forbes             False
# Amy Byrnes               False
# Amy Gregorovich          False
# Andrea Broadfoot         False
# Andrew Bartlett          False
# Andrew Bock              False
# Andrew Braddock          False
# ...                        ...     ...     ...      ...       ...
# Tony Smith                True
# Tony Zappia               True
# Tracey Bell              False
# Tracey Burton            False
# Travis Barker            False
# Travis Carter            False
# Trent Zimmerman           True
# Trevor Evans              True
# Trevor Gray              False
# Trevor Jones             False
# Troy Kay                 False
# Tyler Walsh              False
# Vaughan Williams         False
# Vince Connelly           False
# Vinita Costantino        False
# Virginia Thomas-Wurth    False
# Wade Rothery             False
# Warnar Spyker            False
# Warren Entsch             True
# Warren Mundine           False
# Warren Snowdon            True
# Wayne Connolly           False
# Wayne Sanford            False
# Wayne Swan                True
# William Hornstra         False
# Wylie Campbell           False
# Yvonne Langenberg        False
# Zac Beers                False
# Zali Steggall            False
# Zephlyn Taylor           False
#
# [707 rows x 9 columns]

# %% [markdown]
# ## Electorates

# %%
electorates = election2019.abc.build_electorates()

# %%
electorates
# Out:
#                         name state  \
# Adelaide            Adelaide    SA
# Aston                  Aston   VIC
# Ballarat            Ballarat   VIC
# Banks                  Banks   NSW
# Barker                Barker    SA
# Barton                Barton   NSW
# Bass                    Bass    TA
# Bean                    Bean   ACT
# Bendigo              Bendigo   VIC
# Bennelong          Bennelong   NSW
# Berowra              Berowra   NSW
# Blair                  Blair   QLD
# Blaxland            Blaxland   NSW
# Bonner                Bonner   QLD
# Boothby              Boothby    SA
# Bowman                Bowman   QLD
# Braddon              Braddon    TA
# Bradfield          Bradfield   NSW
# Brand                  Brand    WA
# Brisbane            Brisbane   QLD
# Bruce                  Bruce   VIC
# Burt                    Burt    WA
# Calare                Calare   NSW
# Calwell              Calwell   VIC
# Canberra            Canberra   ACT
# Canning              Canning    WA
# Capricornia      Capricornia   QLD
# Casey                  Casey   VIC
# Chifley              Chifley   NSW
# Chisholm            Chisholm   VIC
# ...                      ...   ...
# Parkes                Parkes   NSW
# Parramatta        Parramatta   NSW
# Paterson            Paterson   NSW
# Pearce                Pearce    WA
# Perth                  Perth    WA
# Petrie                Petrie   QLD
# Rankin                Rankin   QLD
# Reid                    Reid   NSW
# Richmond            Richmond   NSW
# Riverina            Riverina   NSW
# Robertson          Robertson   NSW
# Ryan                    Ryan   QLD
# Scullin              Scullin   VIC
# Shortland          Shortland   NSW
# Solomon              Solomon    NT
# Spence                Spence    SA
# Stirling            Stirling    WA
# Sturt                  Sturt    SA
# Swan                    Swan    WA
# Sydney                Sydney   NSW
# Tangney              Tangney    WA
# Wannon                Wannon   VIC
# Warringah          Warringah   NSW
# Watson                Watson   NSW
# Wentworth (*)  Wentworth (*)   NSW
# Werriwa              Werriwa   NSW
# Whitlam              Whitlam   NSW
# Wide Bay            Wide Bay   QLD
# Wills                  Wills   VIC
# Wright                Wright   QLD
#
#                                                              url party  margin
# Adelaide       https://www.abc.net.au/news/elections/federal/...   ALP     8.3
# Aston          https://www.abc.net.au/news/elections/federal/...   LIB     7.4
# Ballarat       https://www.abc.net.au/news/elections/federal/...   ALP     7.4
# Banks          https://www.abc.net.au/news/elections/federal/...   LIB     1.4
# Barker         https://www.abc.net.au/news/elections/federal/...   LIB    13.9
# Barton         https://www.abc.net.au/news/elections/federal/...   ALP     8.3
# Bass           https://www.abc.net.au/news/elections/federal/...   ALP     5.4
# Bean           https://www.abc.net.au/news/elections/federal/...   ALP     8.9
# Watson         https://www.abc.net.au/news/elections/federal/...   ALP    17.6
# Wentworth (*)  https://www.abc.net.au/news/elections/federal/...   IND     1.0
# Werriwa        https://www.abc.net.au/news/elections/federal/...   ALP     8.2
# Whitlam        https://www.abc.net.au/news/elections/federal/...   ALP    13.7
# Wide Bay       https://www.abc.net.au/news/elections/federal/...   LNP     8.2
# Wills          https://www.abc.net.au/news/elections/federal/...   ALP     4.9
# Wright         https://www.abc.net.au/news/elections/federal/...   LNP     9.6
#
# [151 rows x 5 columns]

# %% [markdown]
# # Gather external candidate data

# %% [markdown]
# ## Scrape ABC candidates' websites
# Scrape the websites linked to in each of the candidates' profiles

# %%
election2019.abc.scrape_candidate_websites(electorates, candidates)
# Out:
# HBox(children=(IntProgress(value=0, max=151), HTML(value='')))

# %%
candidates
# Out:
#                        first_name   family_name party       electorate  \
# Aaron Hammond               Aaron       Hammond   SCP           Sydney
# Aaron Harpley-Carr          Aaron  Harpley-Carr   UAP           Dobell
# Aaron Santelises            Aaron    Santelises   ALP        McPherson
# Aaron Whittaker             Aaron     Whittaker   UAP         Brisbane
# Adam Bandt                   Adam         Bandt   GRN        Melbourne
# Adam Blakester               Adam     Blakester   IND      New England
# Adam Holt                    Adam          Holt   UAP           Sydney
# Adam Pulford                 Adam       Pulford   GRN            Wills
# Adam Veitch                  Adam        Veitch   UAP          Bendigo
# Adam Watson                  Adam        Watson   UAP  Kingsford Smith
# Alan Quinn                   Alan         Quinn   GRN        McPherson
# Alan Tudge                   Alan         Tudge   LIB            Aston
# Alex Hawke                   Alex         Hawke   LIB         Mitchell
# Ali France                    Ali        France   ALP          Dickson
# Alice Thompson              Alice      Thompson   IND        Mackellar
# Alicia Payne               Alicia         Payne   ALP         Canberra
# Alicia Walker              Alicia        Walker   AJP          Higgins
# Allan Green                 Allan         Green   LIB         Greenway
# Allan Roark                 Allan         Roark   UAP             Bass
# Alyce Nelligan              Alyce      Nelligan   GRN            Groom
# Amanda Rishworth           Amanda     Rishworth   ALP         Kingston
# Amanda Wilmot              Amanda        Wilmot   LIB  Kingsford Smith
# Amanda-Sue Markham     Amanda-Sue       Markham   LIB            Clark
# Amber Forbes                Amber        Forbes   GRN            Corio
# Amy Byrnes                    Amy        Byrnes   AJP          Hinkler
# Amy Gregorovich               Amy   Gregorovich   GRN         La Trobe
# Andrea Broadfoot           Andrea     Broadfoot    CA             Grey
# Andrew Bartlett            Andrew      Bartlett   GRN         Brisbane
# Andrew Bock                Andrew          Bock   IND         Nicholls
# Andrew Braddock            Andrew      Braddock   GRN           Fenner
# ...                           ...           ...   ...              ...
# Tony Smith                   Tony         Smith   LIB            Casey
# Tony Zappia                  Tony        Zappia   ALP            Makin
# Tracey Bell                Tracey          Bell   ALP        Moncrieff
# Tracey Burton              Tracey        Burton   GRN           Fisher
# Travis Barker              Travis        Barker   AJP            Casey
# Travis Carter              Travis        Carter   ONP            Brand
# Trent Zimmerman             Trent     Zimmerman   LIB     North Sydney
# Trevor Evans               Trevor         Evans   LNP         Brisbane
# Trevor Gray                Trevor          Gray   UAP           Fisher
# Trevor Jones               Trevor         Jones   IND          Boothby
# Troy Kay                     Troy           Kay   ALP            Groom
# Tyler Walsh                 Tyler         Walsh   ONP            Moore
# Vaughan Williams          Vaughan      Williams   ONP          Bendigo
# Vince Connelly              Vince      Connelly   LIB         Stirling
# Vinita Costantino          Vinita    Costantino   AJP           Deakin
# Virginia Thomas-Wurth    Virginia  Thomas-Wurth   AJP             Swan
# Wade Rothery                 Wade       Rothery   ONP      Capricornia
# Warnar Spyker              Warnar        Spyker   AUC             Burt
# Warren Entsch              Warren        Entsch   LNP       Leichhardt
# Warren Mundine             Warren       Mundine   LIB          Gilmore
# Warren Snowdon             Warren       Snowdon   ALP         Lingiari
# Wayne Connolly              Wayne      Connolly   UAP        Goldstein
# Wayne Sanford               Wayne       Sanford   ALP          Forrest
# Wayne Swan                  Wayne          Swan   ALP           Lilley
# William Hornstra          William      Hornstra   GRN           Monash
# Wylie Campbell              Wylie      Campbell   GRN        Shortland
# Yvonne Langenberg          Yvonne    Langenberg   ALP      New England
# Zac Beers                     Zac         Beers   ALP            Flynn
# Zali Steggall                Zali      Steggall   IND        Warringah
# Zephlyn Taylor            Zephlyn        Taylor   GRN           Wannon
#
#                        sitting  \
# Aaron Hammond            False
# Aaron Harpley-Carr       False
# Aaron Santelises         False
# Aaron Whittaker          False
# Adam Bandt                True
# Adam Blakester           False
# Adam Holt                False
# Adam Pulford             False
# Adam Veitch              False
# Adam Watson              False
# Alan Quinn               False
# Alan Tudge                True
# Alex Hawke                True
# Ali France               False
# Alice Thompson           False
# Alicia Payne             False
# Alicia Walker            False
# Allan Green              False
# Allan Roark              False
# Alyce Nelligan           False
# Amanda Rishworth          True
# Amanda Wilmot            False
# Amanda-Sue Markham       False
# Amber Forbes             False
# Amy Byrnes               False
# Amy Gregorovich          False
# Andrea Broadfoot         False
# Andrew Bartlett          False
# Andrew Bock              False
# Andrew Braddock          False
# ...                        ...
# Tony Smith                True
# Tony Zappia               True
# Tracey Bell              False
# Tracey Burton            False
# Travis Barker            False
# Travis Carter            False
# Trent Zimmerman           True
# Trevor Evans              True
# Trevor Gray              False
# Trevor Jones             False
# Troy Kay                 False
# Tyler Walsh              False
# Vaughan Williams         False
# Vince Connelly           False
# Vinita Costantino        False
# Virginia Thomas-Wurth    False
# Wade Rothery             False
# Warnar Spyker            False
# Warren Entsch             True
# Warren Mundine           False
# Warren Snowdon            True
# Wayne Connolly           False
# Wayne Sanford            False
# Wayne Swan                True
# William Hornstra         False
# Wylie Campbell           False
# Yvonne Langenberg        False
# Zac Beers                False
# Zali Steggall            False
# Zephlyn Taylor           False
#
#                                                                  website  \
# Aaron Hammond
# Aaron Harpley-Carr
# Aaron Santelises       https://www.alp.org.au/our-people/our-people/a...
# Aaron Whittaker
# Adam Bandt                   https://greens.org.au/vic/person/adam-bandt
# Adam Blakester                           https://www.adamblakester.vote/
# Adam Holt
# Adam Pulford
# Adam Veitch
# Adam Watson
# Alan Quinn                   https://greens.org.au/qld/person/alan-quinn
# Alan Tudge                                  http://www.alantudge.com.au/
# Alex Hawke
# Ali France             https://www.alp.org.au/our-people/our-people/a...
# Alice Thompson                             https://alicethompson.com.au/
# Warren Snowdon
# Wayne Connolly
# Wayne Sanford
# Wayne Swan
# William Hornstra
# Wylie Campbell
# Yvonne Langenberg
# Zac Beers
# Zali Steggall           zalisteggall
# Zephlyn Taylor
#
#                                                                 facebook  \
# Aaron Hammond
# Aaron Harpley-Carr
# Aaron Santelises                                    santelises4mcpherson
# Aaron Whittaker
# Adam Bandt                                                 adam.bandt.mp
# Adam Blakester                                             adamblakester
# Adam Holt
# Adam Pulford
# Adam Veitch
# Adam Watson
# Alan Quinn             alan-quinn-greens-candidate-for-mcpherson-3393...
# Alan Tudge                                                   alantudgemp
# Alex Hawke
# Ali France                                             alifrance4dickson
# Alice Thompson                                           alice4mackellar
# Alicia Payne
# Alicia Walker
# Allan Green                                        allangreenforgreenway
# Allan Roark
# Alyce Nelligan                                      alycenelligan.greens
# Amanda Rishworth
# Amanda Wilmot                              amandawilmotforkingsfordsmith
# Amanda-Sue Markham                                       458494798228929
# Amber Forbes
# Amy Byrnes
# Amy Gregorovich                                   amy.gregorovich.greens
# Andrea Broadfoot
# Andrew Bartlett
# Andrew Bock                                                bock4nicholls
# Andrew Braddock                                           braddockandrew
# ...                                                                  ...
# Tony Smith
# Tony Zappia
# Tracey Bell
# Tracey Burton                                         tracyburton.greens
# Travis Barker
# Travis Carter
# Trent Zimmerman
# Trevor Evans
# Trevor Gray
# Trevor Jones           trevor-jones-independent-for-boothby-554705301...
# Troy Kay
# Tyler Walsh
# Vaughan Williams
# Vince Connelly
# Vinita Costantino
# Virginia Thomas-Wurth
# Wade Rothery
# Warnar Spyker
# Warren Entsch                                             warrenentschmp
# Warren Mundine
# Warren Snowdon
# Wayne Connolly
# Wayne Sanford
# Wayne Swan
# William Hornstra                                   williamhornstragreens
# Wylie Campbell
# Yvonne Langenberg                                       labor4newengland
# Zac Beers                                               zacbeersforflynn
# Zali Steggall                                             zali4warringah
# Zephlyn Taylor
#
#                                   instagram
# Aaron Hammond
# Aaron Harpley-Carr
# Aaron Santelises       santelises4mcpherson
# Aaron Whittaker
# Adam Bandt
# Adam Blakester            campaignblakester
# Adam Holt
# Adam Pulford
# Adam Veitch
# Adam Watson
# Alan Quinn
# Alan Tudge
# Alex Hawke
# Ali France                alifrance4dickson
# Alice Thompson
# Alicia Payne
# Alicia Walker
# Allan Green
# Allan Roark
# Alyce Nelligan
# Amanda Rishworth
# Amanda Wilmot
# Amanda-Sue Markham
# Amber Forbes
# Amy Byrnes
# Amy Gregorovich
# Andrea Broadfoot
# Andrew Bartlett
# Andrew Bock
# Andrew Braddock
# ...                                     ...
# Tony Smith
# Tony Zappia
# Tracey Bell
# Tracey Burton
# Travis Barker
# Travis Carter
# Trent Zimmerman
# Trevor Evans
# Trevor Gray
# Trevor Jones
# Troy Kay
# Tyler Walsh
# Vaughan Williams
# Vince Connelly
# Vinita Costantino
# Virginia Thomas-Wurth
# Wade Rothery
# Warnar Spyker
# Warren Entsch              warren.entsch.mp
# Warren Mundine
# Warren Snowdon
# Wayne Connolly
# Wayne Sanford
# Wayne Swan
# William Hornstra
# Wylie Campbell
# Yvonne Langenberg          yvonnenewengland
# Zac Beers
# Zali Steggall                  zalisteggall
# Zephlyn Taylor
#
# [707 rows x 9 columns]

# %%
candidates.replace("", np.nan).count()
# Out:
# first_name     707
# family_name    707
# party          707
# electorate     707
# sitting        707
# website        341
# twitter         64
# facebook       231
# instagram       54
# dtype: int64

# %% [markdown]
# ## Scrape Liberal party candidates website
# Use selenium to manipulate page, and then dump the DOM

# %%
import election2019.liberals

# %%
election2019.liberals.parse_html(candidates)

# %%
candidates.replace("", np.nan).count()
# Out:
# first_name     707
# family_name    707
# party          707
# electorate     707
# sitting        707
# website        341
# twitter        120
# facebook       311
# instagram       92
# dtype: int64

# %% [markdown]
# ## Scrape Labor party candidates website
# Scrape the linked pages for links

# %%
import election2019.labor

# %%
election2019.labor.scrape_candidates_pages(candidates)
# Out:
# HBox(children=(IntProgress(value=0, max=185), HTML(value='')))

# %%
candidates.replace("", np.nan).count()
# Out:
# first_name     707
# family_name    707
# party          707
# electorate     707
# sitting        707
# website        341
# twitter        181
# facebook       398
# instagram      111
# dtype: int64

# %% [markdown]
# ## Scrape Nationals party candidates website
# Scrape the page for links

# %%
import election2019.nationals

# %%
election2019.nationals.scrape_candidates_page(candidates)
election2019.nationals.scrape_members_page(candidates)

# %%
candidates.replace("", np.nan).count()
# Out:
# first_name     707
# family_name    707
# party          707
# electorate     707
# sitting        707
# website        341
# twitter        186
# facebook       415
# instagram      111
# dtype: int64

# %% [markdown]
# ## Scrape Greens candidates website
# Scrape the linked pages for links

# %%
import election2019.greens

# %%
election2019.greens.scrape_candidates_pages(candidates)

# %%
candidates.replace("", np.nan).count()
# Out:
# first_name     707
# family_name    707
# party          707
# electorate     707
# sitting        707
# website        341
# twitter        192
# facebook       422
# instagram      117
# dtype: int64

# %% [markdown]
# ## Scrape United Australia Party candidates website
# Get pages from the API, then scrape links from pages

# %%
import election2019.uap

# %%
election2019.uap.scrape_candidates_pages(candidates)
# Out:
# HBox(children=(IntProgress(value=0, max=151), HTML(value='')))

# %%
candidates.replace("", np.nan).count()
# Out:
# first_name     707
# family_name    707
# party          707
# electorate     707
# sitting        707
# website        341
# twitter        192
# facebook       528
# instagram      117
# dtype: int64

# %% [markdown]
# ## Scrape Pauline Hanson's One Nation candidates website
# Use selenium to access page and defeat bot-detection, then dump and scrape DOM

# %%
import election2019.phon

# %%
election2019.phon.scrape_candidates_page(candidates)

# %%
candidates.replace("", np.nan).count()
# Out:
# first_name     707
# family_name    707
# party          707
# electorate     707
# sitting        707
# website        341
# twitter        192
# facebook       550
# instagram      117
# dtype: int64

# %% [markdown]
# # Validation
#
# Identify candidates that have the same accounts

# %% [markdown]
# ### Twitter

# %%
twitter_dups = candidates["twitter"].replace("", np.nan).dropna().duplicated()

# %%
candidates.loc[twitter_dups[twitter_dups == True].index]
# Out:
# Empty DataFrame
# Columns: [first_name, family_name, party, electorate, sitting, website, twitter, facebook, instagram]
# Index: []

# %% [markdown]
# ### Facebook

# %%
facebook_dups = candidates["facebook"].replace("", np.nan).dropna().duplicated()

# %%
candidates.loc[facebook_dups[facebook_dups == True].index]
# Out:
#                  first_name family_name party electorate  sitting  \
# Hemant Dave          Hemant        Dave   LIB      Makin    False
# Patrick Conaghan    Patrick    Conaghan   NAT     Cowper    False
# Peter Schuback        Peter    Schuback   AFN    Longman    False
# Robert Shearman      Robert    Shearman   LNP      Blair    False
# Susan Jakobi          Susan      Jakobi   AFN      Lalor    False
#
#                                                             website twitter  \
# Hemant Dave           https://www.liberal.org.au/member/hemant-dave
# Patrick Conaghan
# Peter Schuback    https://australiafirstparty.net/campaigns/2019...
# Robert Shearman   https://www.liberal.org.au/member/robert-shearman
# Susan Jakobi      https://australiafirstparty.net/campaigns/2019...
#
#                                                            facebook instagram
# Hemant Dave                                         458494798228929
# Patrick Conaghan  patrick-conaghan-candidate-for-cowper-11594598...
# Peter Schuback    dr-jim-saleam-for-cootamundra-for-an-ideologic...
# Robert Shearman                                     458494798228929
# Susan Jakobi      dr-jim-saleam-for-cootamundra-for-an-ideologic...

# %% [markdown]
# ### Instagram

# %%
instagram_dups = candidates["instagram"].replace("", np.nan).dropna().duplicated()

# %%
candidates.loc[instagram_dups[instagram_dups == True].index]
# Out:
# Empty DataFrame
# Columns: [first_name, family_name, party, electorate, sitting, website, twitter, facebook, instagram]
# Index: []

# %% [markdown]
# # Statistics

# %% [markdown]
# Totals for each source:

# %%
candidates[["twitter", "facebook", "instagram", "website", "first_name"]].rename(columns={"first_name": "total"}).replace("", np.nan).count()
# Out:
# twitter      192
# facebook     550
# instagram    117
# website      341
# total        707
# dtype: int64

# %% [markdown]
# Totals for each party:

# %%
candidates[["party", "twitter", "facebook", "instagram", "website", "first_name"]].rename(columns={"first_name": "total"}).replace("", np.nan).groupby(["party"]).count()
# Out:
#        twitter  facebook  instagram  website  total
# party
# AFN          0         3          0        3      3
# AJP          0         0          0       13     24
# ALP         82       143         46       62    152
# AUC          0         0          0        0     11
# CA           0         0          0        2      3
# CEC          0         0          0        0      2
# CLP          0         2          1        1      2
# GRN         19       110         15      140    143
# IND         20        21         13       26     30
# KAP          0         1          0        5      6
# LAL          1         1          0        1      1
# LIB         44        89         33       27    101
# LNP         17        28          7       17     32
# NAT          9        24          2       10     24
# ONP          0        22          0       23     23
# PROG         0         0          0        4      5
# SAP          0         0          0        3      3
# SCP          0         0          0        0      8
# UAP          0       106          0        0    130
# VS           0         0          0        3      3
# WAP          0         0          0        1      1

# %% [markdown]
# Incumbents vs candidates:

# %%
candidates[["sitting", "twitter", "facebook", "instagram", "website"]].replace("", np.nan).groupby(["sitting"]).count()
# Out:
#          twitter  facebook  instagram  website
# sitting
# False         67       410         71      308
# True         125       140         46       33

# %% [markdown]
# # Save data

# %%
import ipywidgets as widgets
from IPython.display import display
button = widgets.Button(description="Save")
display(button)
from time import time
import pickle
import os

def on_button_clicked(b):
    save_time = int(time())
    pre_str = os.path.join(os.getcwd(), 'output/')
    candidates.to_json(f"{pre_str}{save_time}_candidates.json")
    candidates.to_csv(f"{pre_str}{save_time}_candidates.csv")
    electorates.to_json(f"{pre_str}{save_time}_electorates.json")
    electorates.to_csv(f"{pre_str}{save_time}_electorates.csv")
    print(f"Saved to {pre_str}")

button.on_click(on_button_clicked)
# Out:
# Button(description='Save', style=ButtonStyle())
